# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Rename.csv")
df
# Out:
#      Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS  \
# 0      Male   70                    181                  262             0
# 1    Female   55                    103                  253             1
# 2      Male   42                     95                  295             1
# 3      Male   84                    106                  270             0
# 4      Male   86                    187                  296             1
# ..      ...  ...                    ...                  ...           ...
# 995    Male   42                    125                  193             1
# 996    Male   80                    186                  267             1
# 997  Female   64                    108                  174             1
# 998  Female   84                    123                  195             0
# 999    Male   61                    155                  197             0
#
# ...

# %%
df.describe()
# Out:
#                Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS
# count  1000.000000            1000.000000          1000.000000   1000.000000
# mean     60.338000             145.440000           223.789000      0.517000
# std      17.317496              31.756525            42.787817      0.499961
# min      30.000000              90.000000           150.000000      0.000000
# 25%      45.000000             118.000000           185.000000      0.000000
# 50%      60.500000             146.000000           225.500000      1.000000
# 75%      76.000000             173.000000           259.000000      1.000000
# max      89.000000             199.000000           299.000000      1.000000

# %%
df.head()
# Out:
#    Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS  \
# 0    Male   70                    181                  262             0
# 1  Female   55                    103                  253             1
# 2    Male   42                     95                  295             1
# 3    Male   84                    106                  270             0
# 4    Male   86                    187                  296             1
#
#   Smoking Status  Chest Pain Type                            Treatment
# 0          Never   Typical Angina                    Lifestyle Changes
# 1          Never  Atypical Angina                          Angioplasty
# 2        Current   Typical Angina                          Angioplasty
# 3          Never  Atypical Angina  Coronary Artery Bypass Graft (CABG)
# 4        Current  0n-anginal Pain                           Medication

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 1000 non-null   object
#  1   Age                    1000 non-null   int64
#  2   Blood Pressure (mmHg)  1000 non-null   int64
#  3   Cholesterol (mg/dL)    1000 non-null   int64
#  4   DIABETES_HAS           1000 non-null   int64
#  5   Smoking Status         1000 non-null   object
#  6   Chest Pain Type        1000 non-null   object
#  7   Treatment              1000 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 265.2 KB

# %%
df=pd.read_csv("Rename.csv",nrows=30)
df
# Out:
#     Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS  \
# 0     Male   70                    181                  262             0
# 1   Female   55                    103                  253             1
# 2     Male   42                     95                  295             1
# 3     Male   84                    106                  270             0
# 4     Male   86                    187                  296             1
# 5   Female   66                    125                  271             1
# 6     Male   33                    181                  262             1
# 7     Male   84                    182                  288             0
# 8     Male   73                    115                  286             1
# 9   Female   63                    174                  254             1
# 10    Male   88                    154                  150             0
# 11    Male   69                    133                  236             0
# ...

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 30 non-null     object
#  1   Age                    30 non-null     int64
#  2   Blood Pressure (mmHg)  30 non-null     int64
#  3   Cholesterol (mg/dL)    30 non-null     int64
#  4   DIABETES_HAS           30 non-null     int64
#  5   Smoking Status         30 non-null     object
#  6   Chest Pain Type        30 non-null     object
#  7   Treatment              30 non-null     object
# dtypes: int64(4), object(4)
# memory usage: 8.1 KB

# %%
df.head()
# Out:
#    Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS  \
# 0    Male   70                    181                  262             0
# 1  Female   55                    103                  253             1
# 2    Male   42                     95                  295             1
# 3    Male   84                    106                  270             0
# 4    Male   86                    187                  296             1
#
#   Smoking Status  Chest Pain Type                            Treatment
# 0          Never   Typical Angina                    Lifestyle Changes
# 1          Never  Atypical Angina                          Angioplasty
# 2        Current   Typical Angina                          Angioplasty
# 3          Never  Atypical Angina  Coronary Artery Bypass Graft (CABG)
# 4        Current  0n-anginal Pain                           Medication

# %%
df.tail()
# Out:
#     Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS  \
# 25  Female   89                    112                  209             0
# 26  Female   84                    197                  273             1
# 27  Female   61                    149                  157             1
# 28  Female   52                    104                  191             0
# 29  Female   49                    159                  268             0
#
#    Smoking Status  Chest Pain Type                            Treatment
# 25        Current  0n-anginal Pain                          Angioplasty
# 26         Former   Typical Angina                    Lifestyle Changes
# 27         Former   Typical Angina  Coronary Artery Bypass Graft (CABG)
# 28          Never  0n-anginal Pain                          Angioplasty
# 29        Current     Asymptomatic                    Lifestyle Changes

# %%
df1=pd.read_csv("Rename.csv",nrows=10)
df1
# Out:
#    Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS  \
# 0    Male   70                    181                  262             0
# 1  Female   55                    103                  253             1
# 2    Male   42                     95                  295             1
# 3    Male   84                    106                  270             0
# 4    Male   86                    187                  296             1
# 5  Female   66                    125                  271             1
# 6    Male   33                    181                  262             1
# 7    Male   84                    182                  288             0
# 8    Male   73                    115                  286             1
# 9  Female   63                    174                  254             1
#
#   Smoking Status  Chest Pain Type                            Treatment
# 0          Never   Typical Angina                    Lifestyle Changes
# ...

# %%
df
# Out:
#     Gender  Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)  DIABETES_HAS  \
# 0     Male   70                    181                  262             0
# 1   Female   55                    103                  253             1
# 2     Male   42                     95                  295             1
# 3     Male   84                    106                  270             0
# 4     Male   86                    187                  296             1
# 5   Female   66                    125                  271             1
# 6     Male   33                    181                  262             1
# 7     Male   84                    182                  288             0
# 8     Male   73                    115                  286             1
# 9   Female   63                    174                  254             1
# 10    Male   88                    154                  150             0
# 11    Male   69                    133                  236             0
# ...

# %%
final=df.drop(['DIABETES_HAS','Gender','Smoking Status', 'Chest Pain Type', 'Treatment'],axis='columns')
final
# Out:
#     Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)
# 0    70                    181                  262
# 1    55                    103                  253
# 2    42                     95                  295
# 3    84                    106                  270
# 4    86                    187                  296
# 5    66                    125                  271
# 6    33                    181                  262
# 7    84                    182                  288
# 8    73                    115                  286
# 9    63                    174                  254
# 10   88                    154                  150
# 11   69                    133                  236
# 12   78                    165                  171
# 13   89                    153                  215
# 14   71                    110                  182
# 15   30                    107                  242
# 16   77                    112                  179
# ...

# %%
print(df.columns)
# Out:
# Index(['Gender', 'Age', 'Blood Pressure (mmHg)', 'Cholesterol (mg/dL)',
#        'DIABETES_HAS', 'Smoking Status', 'Chest Pain Type', 'Treatment'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
p=final
p
# Out:
#     Age  Blood Pressure (mmHg)  Cholesterol (mg/dL)
# 0    70                    181                  262
# 1    55                    103                  253
# 2    42                     95                  295
# 3    84                    106                  270
# 4    86                    187                  296
# 5    66                    125                  271
# 6    33                    181                  262
# 7    84                    182                  288
# 8    73                    115                  286
# 9    63                    174                  254
# 10   88                    154                  150
# 11   69                    133                  236
# 12   78                    165                  171
# 13   89                    153                  215
# 14   71                    110                  182
# 15   30                    107                  242
# 16   77                    112                  179
# ...

# %%
k=df.DIABETES_HAS

# %%
model.fit(p,k)
# Out:
# LinearRegression()

# %%
model.predict([[70,185,295]])
# Out:
# C:\Users\pranj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.59341232])

# %%
model.score(p,k)
# Out:
# 0.0649930097879825

# %%
import seaborn as sns
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
import matplotlib.pyplot as plt
df.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Blood Pressure (mmHg)'}>],
#        [<Axes: title={'center': 'Cholesterol (mg/dL)'}>,
#         <Axes: title={'center': 'DIABETES_HAS'}>]], dtype=object)

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Age', 'Blood Pressure (mmHg)', 'Cholesterol (mg/dL)', 'DIABETES_HAS'], dtype='object')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Rename.csv")
for i in ['Age', 'Blood Pressure (mmHg)', 'Cholesterol (mg/dL)', 'DIABETES_HAS']:
    sns.scatterplot(data=df,x=i,y='DIABETES_HAS')
    plt.show()

# %% [raw]
# THANK YOU
